# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sqlite3
from pandas.io import sql
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
print("="*45)
print ("Capstone Project - Insurance Premium Data")
print("="*45)
# Out:
# =============================================
# Capstone Project - Insurance Premium Data
# =============================================

# %%
# Start of Exploratory Data Analysis

# %%
insurance = "insurance.csv"
df = pd.read_csv(insurance, encoding = 'utf-8')
pd.set_option('precision', 1)
df.head()
# Out:
#    age     sex   bmi  children smoker     region  charges    age_group  \
# 0   19  female  27.9         0    yes  southwest  16884.9        Youth
# 1   18    male  33.8         1     no  southeast   1725.6        Youth
# 2   28    male  33.0         3     no  southeast   4449.5  Millennials
# 3   33    male  22.7         0     no  northwest  21984.5  Millennials
# 4   32    male  28.9         0     no  northwest   3866.9  Millennials
#
#    bmi_status
# 0  Overweight
# 1  Overweight
# 2  Overweight
# 3     Healthy
# 4  Overweight

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1338 non-null   int64
#  1   sex         1338 non-null   object
#  2   bmi         1338 non-null   float64
#  3   children    1338 non-null   int64
#  4   smoker      1338 non-null   object
#  5   region      1338 non-null   object
#  6   charges     1338 non-null   float64
#  7   age_group   1338 non-null   object
#  8   bmi_status  1338 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 94.2+ KB

# %%
column_names = ['Age', 'Gender', 'BMI', "Children", 'Smoker', 'Region', 'Total_charges', 'Age_group', 'BMI_status']
df = pd.read_csv(insurance, names=column_names, skiprows=1)
df.head()
# Out:
#    Age  Gender   BMI  Children Smoker     Region  Total_charges    Age_group  \
# 0   19  female  27.9         0    yes  southwest        16884.9        Youth
# 1   18    male  33.8         1     no  southeast         1725.6        Youth
# 2   28    male  33.0         3     no  southeast         4449.5  Millennials
# 3   33    male  22.7         0     no  northwest        21984.5  Millennials
# 4   32    male  28.9         0     no  northwest         3866.9  Millennials
#
#    BMI_status
# 0  Overweight
# 1  Overweight
# 2  Overweight
# 3     Healthy
# 4  Overweight

# %%
df.isnull().sum()
# Out:
# Age              0
# Gender           0
# BMI              0
# Children         0
# Smoker           0
# Region           0
# Total_charges    0
# Age_group        0
# BMI_status       0
# dtype: int64

# %%
df.describe()
# Out:
#           Age     BMI  Children  Total_charges
# count  1338.0  1338.0    1338.0         1338.0
# mean     39.2    30.7       1.1        13270.4
# std      14.0     6.1       1.2        12110.0
# min      18.0    16.0       0.0         1121.9
# 25%      27.0    26.3       0.0         4740.3
# 50%      39.0    30.4       1.0         9382.0
# 75%      51.0    34.7       2.0        16639.9
# max      64.0    53.1       5.0        63770.4

# %%
df[df['Gender'] == 'male']
# Out:
#       Age Gender   BMI  Children Smoker     Region  Total_charges  \
# 1      18   male  33.8         1     no  southeast         1725.6
# 2      28   male  33.0         3     no  southeast         4449.5
# 3      33   male  22.7         0     no  northwest        21984.5
# 4      32   male  28.9         0     no  northwest         3866.9
# 8      37   male  29.8         2     no  northeast         6406.4
# ...   ...    ...   ...       ...    ...        ...            ...
# 1324   31   male  25.9         1     no  northwest         4239.9
# 1325   61   male  33.5         0     no  northeast        13143.3
# 1327   51   male  30.0         1     no  southeast         9377.9
# 1329   52   male  38.6         2     no  southwest        10325.2
# 1333   50   male  31.0         3     no  northwest        10600.5
#
#         Age_group  BMI_status
# 1           Youth  Overweight
# 2     Millennials  Overweight
# 3     Millennials     Healthy
# 4     Millennials  Overweight
# 8     Millennials  Overweight
# ...           ...         ...
# 1324  Millennials  Overweight
# 1325      Boomers  Overweight
# 1327        Gen X  Overweight
# 1329        Gen X  Overweight
# 1333        Gen X  Overweight
#
# [676 rows x 9 columns]

# %%
df[df['Gender'] == 'female']
# Out:
#       Age  Gender   BMI  Children Smoker     Region  Total_charges  \
# 0      19  female  27.9         0    yes  southwest        16884.9
# 5      31  female  25.7         0     no  southeast         3756.6
# 6      46  female  33.4         1     no  southeast         8240.6
# 7      37  female  27.7         3     no  northwest         7281.5
# 9      60  female  25.8         0     no  northwest        28923.1
# ...   ...     ...   ...       ...    ...        ...            ...
# 1332   52  female  44.7         3     no  southwest        11411.7
# 1334   18  female  31.9         0     no  northeast         2206.0
# 1335   18  female  36.9         0     no  southeast         1629.8
# 1336   21  female  25.8         0     no  southwest         2007.9
# 1337   61  female  29.1         0    yes  northwest        29141.4
#
#         Age_group  BMI_status
# 0           Youth  Overweight
# 5     Millennials  Overweight
# 6           Gen X  Overweight
# 7     Millennials  Overweight
# 9         Boomers  Overweight
# ...           ...         ...
# 1332        Gen X  Overweight
# 1334        Youth  Overweight
# 1335        Youth  Overweight
# 1336        Youth  Overweight
# 1337      Boomers  Overweight
#
# [662 rows x 9 columns]

# %%
df = df.astype(str)

# %%
df[(df['Age'] > '45') & (df['Total_charges'] > '20000')]
# Out:
#      Age  Gender     BMI Children Smoker     Region Total_charges Age_group  \
# 6     46  female   33.44        1     no  southeast     8240.5896     Gen X
# 9     60  female   25.84        0     no  northwest   28923.13692   Boomers
# 11    62  female   26.29        0    yes  southeast    27808.7251   Boomers
# 39    60    male    39.9        0    yes  southwest     48173.361   Boomers
# 45    55    male    37.3        0     no  southwest   20630.28351     Gen X
# ...   ..     ...     ...      ...    ...        ...           ...       ...
# 1293  46    male  25.745        3     no  northwest    9301.89355     Gen X
# 1301  62    male  30.875        3    yes  northwest   46718.16325   Boomers
# 1321  62    male  26.695        0    yes  northeast   28101.33305   Boomers
# 1327  51    male   30.03        1     no  southeast     9377.9047     Gen X
# 1337  61  female   29.07        0    yes  northwest    29141.3603   Boomers
#
#       BMI_status
# 6     Overweight
# 9     Overweight
# 11    Overweight
# 39    Overweight
# 45    Overweight
# ...          ...
# 1293  Overweight
# 1301  Overweight
# 1321  Overweight
# 1327  Overweight
# 1337  Overweight
#
# [245 rows x 9 columns]

# %%
df[(df['BMI'] > '25') & (df['Smoker'] == 'yes')]
# Out:
#      Age  Gender     BMI Children Smoker     Region Total_charges  \
# 0     19  female    27.9        0    yes  southwest     16884.924
# 11    62  female   26.29        0    yes  southeast    27808.7251
# 14    27    male   42.13        0    yes  southeast    39611.7577
# 19    30    male    35.3        0    yes  southwest     36837.467
# 23    34  female   31.92        1    yes  northeast    37701.8768
# ...   ..     ...     ...      ...    ...        ...           ...
# 1308  25  female    30.2        0    yes  southwest     33900.653
# 1313  19  female    34.7        2    yes  southwest     36397.576
# 1321  62    male  26.695        0    yes  northeast   28101.33305
# 1323  42  female   40.37        2    yes  southeast    43896.3763
# 1337  61  female   29.07        0    yes  northwest    29141.3603
#
#         Age_group  BMI_status
# 0           Youth  Overweight
# 11        Boomers  Overweight
# 14    Millennials  Overweight
# 19    Millennials  Overweight
# 23    Millennials  Overweight
# ...           ...         ...
# 1308  Millennials  Overweight
# 1313        Youth  Overweight
# 1321      Boomers  Overweight
# 1323        Gen X  Overweight
# 1337      Boomers  Overweight
#
# [219 rows x 9 columns]
